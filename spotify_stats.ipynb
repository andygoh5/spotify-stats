# %%
import pandas as pd
import json
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# ### 1. Setting up the dataframe

# %%
pd.set_option('display.max_rows', None)

# change direc_name to be the name of the folder that you downloaded from Spotify
# it is usually "MyData"
direc_name = "MyData/"
file_list = [direc_name + x for x in os.listdir(direc_name)
             if x.split('.')[0][:-1] == 'StreamingHistory']

dfs = []                                        # an empty list to store the data frames
for file in file_list:
    data = pd.read_json(file)                   # read data frame from json file
    dfs.append(data)                            # append the data frame to the list
df = pd.concat(dfs, ignore_index=True)          # concatenate all the data frames in the list.
df['endTime'] = pd.to_datetime(df['endTime'])
df.head(5)
# Out:
#               endTime artistName                  trackName  msPlayed
# 0 2022-04-19 03:52:00       10cm     Fine Thank You And You    220600
# 1 2022-04-19 03:52:00       10cm  한강의 작별 The Han's Farewell      2226
# 2 2022-04-19 03:53:00       10cm        냄새나는 여자 Smelly Girl      3240
# 3 2022-04-19 03:55:00       10cm                그러니까… So...    122710
# 4 2022-04-19 03:58:00       10cm              That's Not...    228840

# %% [markdown]
# ### 2. Streaming data for the past year

# %%
# get the streams with more than 30 seconds played, as those are the ones that are counted by Spotify
valid_streams= df[df['msPlayed'] > 30000]
total = valid_streams['msPlayed'].sum()
print("Hours listened:", total / 1000.0 / 60.0 / 60.0)
# Out:
# Hours listened: 906.8965127777777

# %%
# get individual stream counts for each track in the past year (entire dataset)
stream_counts =valid_streams.groupby(['artistName','trackName']).size().reset_index(name='Streams').sort_values(by=['Streams'],ascending=False)
path = str(Path().absolute())
stream_counts.to_csv(path + '/entire_year.csv')
stream_counts.head(50)
# Out:
#                 artistName                                        trackName  \
# 2520               TAEYEON                                             INVU
# 2485               TAEYEON                             Can't Control Myself
# 1480         Kim Kyung Rok                                      Sand Castle
# 2558               TAEYEON                                          Toddler
# 2545               TAEYEON                                      Some Nights
# 934                  HEIZE                                           HAPPEN
# 2544               TAEYEON                                            Siren
# 2556               TAEYEON                                         Timeless
# 2488               TAEYEON                                     Cold As Hell
# 2543               TAEYEON                               Set Myself On Fire
# 2495               TAEYEON                                   Ending Credits
# 1765           Michael Tai       A Tender Feeling (From "Sword Art Online")
# 2561               TAEYEON                                            VOICE
# 2511               TAEYEON                                            Heart
# 312                   BUZZ                                               가시
# 2503               TAEYEON                                     Four Seasons
# 2563               TAEYEON                                          Weekend
# 2535               TAEYEON                                    No Love Again
# 1363                K.Will  Back In Time (The Moon during the Day X K.will)
# 2858  Two Door Cinema Club                          Changing of the Seasons
# 1073                    IU                                        Love poem
# 2622          Taylor Swift                               champagne problems
# 2435          Standing Egg                                           오래된 노래
# 2483               TAEYEON                                             Blue
# 2513               TAEYEON                                                I
# 2569               TAEYEON                                   You Better Not
# 2555               TAEYEON                                       Time Lapse
# 2701           The Killers                                            Human
# 2350         Sarah Kinsley                                            Karma
# 142                  Adele                               When We Were Young
# 2564               TAEYEON                               What Do I Call You
# 1972               October                                             From
# 1443         Kenshi Yonezu                                             カナリヤ
# 937                  HEIZE                 Like the first time (Feat. Gary)
# 749                FINNEAS                                  Only A Lifetime
# 2548               TAEYEON                                            Spark
# 593               Coldplay                                    The Scientist
# 1982               October                                            Intro
# 86                    AKMU      Hey kid, Close your eyes (with Lee Sun Hee)
# 1076                    IU                                           My sea
# 2501               TAEYEON                                             Fine
# 1351          Jung Dong Ha                                 I Still Love You
# 2568               TAEYEON                                             Wine
# 2148       Porter Robinson                                          Shelter
# 2566               TAEYEON                                              Why
# 1985               October                                          Journey
# 2507               TAEYEON                                          Gravity
# 1337                Joohyo                                   Northern Light
# 943                  HEIZE                The Walking Dead (Feat. Kim Feel)
# 1675           M.C the Max                                just looking 바라보기
#
#       Streams
# 2520      434
# 2485      374
# 1480      259
# 2558      172
# 2545      168
# 934       158
# 2544      154
# 2556      143
# 2488      139
# 2543      128
# 2495      127
# 1765      123
# 2561      120
# 2511      111
# 312       107
# 2503       97
# 2563       94
# 2535       85
# 1363       82
# 2858       82
# 1073       79
# 2622       76
# 2435       74
# 2483       73
# 2513       72
# 2569       72
# 2555       69
# 2701       67
# 2350       65
# 142        64
# 2564       62
# 1972       57
# 1443       55
# 937        53
# 749        51
# 2548       50
# 593        50
# 1982       47
# 86         46
# 1076       45
# 2501       45
# 1351       45
# 2568       44
# 2148       44
# 2566       44
# 1985       44
# 2507       44
# 1337       43
# 943        41
# 1675       41

# %% [markdown]
# ### 3. Streaming data for 2022

# %%
# get top 10 artists from 2022 and the number of streams
streams_2022 = valid_streams[valid_streams['endTime'] > '2022-01-01']
artist_counts = streams_2022['artistName'].value_counts()
artist_counts.head(10)
# Out:
# TAEYEON          2579
# Kenshi Yonezu     376
# Glen Check        162
# Taylor Swift      134
# 10cm              113
# October           111
# FINNEAS           101
# mol-74             97
# IU                 79
# Michael Tai        57
# Name: artistName, dtype: int64

# %%
# look at streams from 2022 instead of the past year:
streams_2022_counts =streams_2022.groupby(['artistName','trackName']).size().reset_index(name='Streams').sort_values(by=['Streams'],ascending=False)
path = str(Path().absolute())

# output 2022 stream data into 2022.csv
streams_2022_counts.to_csv(path + '/2022.csv')

# %%
# search for a specific song:
song_name = 'INVU'

song_stream_count = streams_2022_counts[streams_2022_counts['trackName'] == song_name]
song_stream_count.head(10)
# Out:
#      artistName trackName  Streams
# 1210    TAEYEON      INVU      434

# %%
# search for a specific artist:
artist_name = 'TAEYEON'

artist_stream_counts = streams_2022_counts[streams_2022_counts['artistName'] == artist_name]
artist_stream_counts.head(50)
# Out:
#      artistName                              trackName  Streams
# 1210    TAEYEON                                   INVU      434
# 1183    TAEYEON                   Can't Control Myself      374
# 1236    TAEYEON                                Toddler      172
# 1228    TAEYEON                            Some Nights      168
# 1227    TAEYEON                                  Siren      154
# 1234    TAEYEON                               Timeless      143
# 1186    TAEYEON                           Cold As Hell      139
# 1226    TAEYEON                     Set Myself On Fire      128
# 1192    TAEYEON                         Ending Credits      127
# 1203    TAEYEON                                  Heart      111
# 1222    TAEYEON                          No Love Again       85
# 1245    TAEYEON                         You Better Not       72
# 1181    TAEYEON                                   Blue       58
# 1239    TAEYEON                                Weekend       48
# 1199    TAEYEON                           Four Seasons       43
# 1233    TAEYEON                             Time Lapse       21
# 1205    TAEYEON                                      I       20
# 1230    TAEYEON                                  Spark       19
# 1244    TAEYEON                                   Wine       16
# 1240    TAEYEON                     What Do I Call You       16
# 1180    TAEYEON                            Better Babe       12
# 1197    TAEYEON                                   Fine       12
# 1195    TAEYEON                           Feel So Fine       12
# 1177    TAEYEON                                  11:11       11
# 1215    TAEYEON                                    LOL       10
# 1242    TAEYEON                                    Why       10
# 1204    TAEYEON                              Here I Am       10
# 1182    TAEYEON                             By My Side        9
# 1196    TAEYEON                                Find Me        9
# 1201    TAEYEON                                Gravity        9
# 1185    TAEYEON                              City Love        8
# 1221    TAEYEON                             My Tragedy        7
# 1218    TAEYEON                    Love You Like Crazy        7
# 1189    TAEYEON                                Dear Me        7
# 1190    TAEYEON                        Do You Love Me?        7
# 1219    TAEYEON                          Love in Color        7
# 1213    TAEYEON                                     If        6
# 1191    TAEYEON                    Drawing Our Moments        6
# 1238    TAEYEON                                  VOICE        5
# 1220    TAEYEON                       Make Me Love You        5
# 1224    TAEYEON                              Rescue Me        5
# 1187    TAEYEON                               Cover Up        4
# 1184    TAEYEON                                 Circus        4
# 1209    TAEYEON                                 I'm OK        4
# 1208    TAEYEON                             I Got Love        4
# 1198    TAEYEON                                   Fire        3
# 1232    TAEYEON                             Sweet Love        3
# 1212    TAEYEON                 INVU - Moon Kyoo Remix        2
# 1214    TAEYEON  Into the Unknown (End Credit Version)        2
# 1217    TAEYEON                           Lonely Night        2

# %% [markdown]
# ### 2022 Spotify Wrapped (so far)

# %%
# see your Spotify Wrapped so far
streams_2022_counts.head(100)
# Out:
#                 artistName                                          trackName  \
# 1210               TAEYEON                                               INVU
# 1183               TAEYEON                               Can't Control Myself
# 1236               TAEYEON                                            Toddler
# 1228               TAEYEON                                        Some Nights
# 1227               TAEYEON                                              Siren
# 1234               TAEYEON                                           Timeless
# 1186               TAEYEON                                       Cold As Hell
# 1226               TAEYEON                                 Set Myself On Fire
# 1192               TAEYEON                                     Ending Credits
# 1203               TAEYEON                                              Heart
# 1222               TAEYEON                                      No Love Again
# 1245               TAEYEON                                     You Better Not
# 1181               TAEYEON                                               Blue
# 663          Kenshi Yonezu                                               カナリヤ
# 1239               TAEYEON                                            Weekend
# 1266          Taylor Swift                                 champagne problems
# 1199               TAEYEON                                       Four Seasons
# 348          Fleetwood Mac                                          Landslide
# 395             Glen Check                                   Dazed & Confused
# 510                     IU                                          Love poem
# 1506                 aespa                                        YEPPI YEPPI
# 649          Kenshi Yonezu                                              Lemon
# 1166                 Sting  What Could Have Been feat. Ray Chen (from the ...
# 7                     10cm                             Fine Thank You And You
# 125                 Basick  Meeting is easy, parting is hard (Feat. Leella...
# 976           Philip Glass  String Quartet No. 3, "Mishima": VI. Mishima /...
# 833            Michael Tai         A Tender Feeling (From "Sword Art Online")
# 1233               TAEYEON                                         Time Lapse
# 321                FINNEAS                                       Love is Pain
# 362        Frédéric Chopin                Nocturnes, Op. 48: No. 1 in C Minor
# 668          Kenshi Yonezu                                            ナンバーナイン
# 1055     Rex Orange County                                         KEEP IT UP
# 1205               TAEYEON                                                  I
# 651          Kenshi Yonezu                                         Nighthawks
# 1230               TAEYEON                                              Spark
# 325                FINNEAS                                    Only A Lifetime
# 1287          Taylor Swift                                  this is me trying
# 100                BIGBANG                                         Still Life
# 11                    10cm                                      That's Not...
# 776                  Lorde                                          Liability
# 1244               TAEYEON                                               Wine
# 798                MC MONG                   Sick enough to die (Feat. JAMIE)
# 1050       Reese Lansangan                              What Is This Feeling?
# 1240               TAEYEON                                 What Do I Call You
# 252               Coldplay                                      The Scientist
# 540                 JAURIM                                            Shining
# 682          Kenshi Yonezu                                                 飛燕
# 1415      Vincent Diamante                                             Flight
# 670          Kenshi Yonezu                                             ピースサイン
# 351          Fleetwood Mac                      Seven Wonders - 2017 Remaster
# 152             Blake Rose                                               Gone
# 648          Kenshi Yonezu                                              LOSER
# 1251   TOMORROW X TOGETHER                                        LO$ER=LO♡ER
# 679          Kenshi Yonezu                                    砂の惑星 ( + 初音ミク )
# 657          Kenshi Yonezu                                              orion
# 81            Anson Seabra                                       Emerald Eyes
# 47                   Adele                                        To Be Loved
# 13                    10cm                                   그대와 나 You And Me
# 411             Glen Check                                              Waves
# 597            John Powell  Romantic Flight - From How To Train Your Drago...
# 48                   Adele                                 When We Were Young
# 1271          Taylor Swift                                          gold rush
# 664          Kenshi Yonezu                                             カムパネルラ
# 619                 Joohyo                                     Northern Light
# 404             Glen Check                                               Sins
# 673          Kenshi Yonezu                     愛麗絲(正式表記はAliceの中国語簡体字表記となります。)
# 1562                mol-74                                             ミラーソング
# 129             Bea Miller                                    i can't breathe
# 19                    10cm                                        스토커 Stalker
# 923                October                                       Recollection
# 330                FINNEAS                          What They'll Say About Us
# 675          Kenshi Yonezu                                               打上花火
# 227   Cigarettes After Sex                                            Sunsetz
# 405             Glen Check                   Sometimes You Gotta Shake It Off
# 1489          Yu-Peng Chen                                    Tender Strength
# 752             Lee Yun Ji                                          My Family
# 977           Philip Glass                                Tales from the Loop
# 1180               TAEYEON                                        Better Babe
# 1197               TAEYEON                                               Fine
# 396             Glen Check                                    Dive Baby, Dive
# 1195               TAEYEON                                       Feel So Fine
# 1552                mol-74                                            Answers
# 1002       Phoebe Bridgers                                           Punisher
# 1177               TAEYEON                                              11:11
# 414          Gracie Abrams                                             Camden
# 1288          Taylor Swift                                        tolerate it
# 662          Kenshi Yonezu                                            まちがいさがし
# 1446               Woodkid  Guns for Hire (from the series Arcane League o...
# 656          Kenshi Yonezu                              fogbound ( + 池田エライザ )
# 678          Kenshi Yonezu                                    灰色と青 ( + 菅田将暉 )
# 624           Jung Dong Ha                                   I Still Love You
# 225   Cigarettes After Sex                                                 K.
# 660          Kenshi Yonezu                                          かいじゅうのマーチ
# 650          Kenshi Yonezu                                          Moonlight
# 1215               TAEYEON                                                LOL
# 1162          Standing Egg                                             오래된 노래
# 758          Lennon Stella                                    Older Than I Am
# 1242               TAEYEON                                                Why
# 677          Kenshi Yonezu                                               海の幽霊
# 748              Lee So Ra                                            Track 9
#
#       Streams
# 1210      434
# 1183      374
# 1236      172
# 1228      168
# 1227      154
# 1234      143
# 1186      139
# 1226      128
# 1192      127
# 1203      111
# 1222       85
# 1245       72
# 1181       58
# 663        55
# 1239       48
# 1266       44
# 1199       43
# 348        30
# 395        30
# 510        29
# 1506       26
# 649        26
# 1166       24
# 7          24
# 125        24
# 976        23
# 833        22
# 1233       21
# 321        21
# 362        21
# 668        20
# 1055       20
# 1205       20
# 651        19
# 1230       19
# 325        18
# 1287       18
# 100        17
# 11         17
# 776        17
# 1244       16
# 798        16
# 1050       16
# 1240       16
# 252        16
# 540        16
# 682        16
# 1415       16
# 670        16
# 351        15
# 152        15
# 648        15
# 1251       15
# 679        15
# 657        15
# 81         15
# 47         15
# 13         15
# 411        15
# 597        14
# 48         14
# 1271       14
# 664        14
# 619        14
# 404        14
# 673        13
# 1562       13
# 129        13
# 19         13
# 923        13
# 330        12
# 675        12
# 227        12
# 405        12
# 1489       12
# 752        12
# 977        12
# 1180       12
# 1197       12
# 396        12
# 1195       12
# 1552       11
# 1002       11
# 1177       11
# 414        11
# 1288       11
# 662        11
# 1446       11
# 656        11
# 678        11
# 624        10
# 225        10
# 660        10
# 650        10
# 1215       10
# 1162       10
# 758        10
# 1242       10
# 677        10
# 748        10

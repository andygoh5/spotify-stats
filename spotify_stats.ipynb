# %%
import pandas as pd
import json
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# ### 1. Setting up the dataframe

# %%
pd.set_option('display.max_rows', None)

# change direc_name to be the name of the folder that you downloaded from Spotify
# it is usually "MyData"
direc_name = "MyData220527/"
file_list = [direc_name + x for x in os.listdir(direc_name)
             if x.split('.')[0][:-1] == 'StreamingHistory']

dfs = []                                        # an empty list to store the data frames
for file in file_list:
    data = pd.read_json(file)                   # read data frame from json file
    dfs.append(data)                            # append the data frame to the list
df = pd.concat(dfs, ignore_index=True)          # concatenate all the data frames in the list.
df['endTime'] = pd.to_datetime(df['endTime'])
df.head(5)
# Out:
#               endTime artistName        trackName  msPlayed
# 0 2022-04-29 17:15:00       HAIM  Up From A Dream     15410
# 1 2022-04-29 17:15:00  Clubhouse          NO WAY!    106460
# 2 2022-04-29 18:13:00       HAIM      Don't Wanna    244360
# 3 2022-04-29 18:16:00      aespa      YEPPI YEPPI    132610
# 4 2022-04-29 20:34:00      aespa      YEPPI YEPPI     80949

# %% [markdown]
# ### 2. Streaming data for the past year

# %%
# get the streams with more than 30 seconds played, as those are the ones that are counted by Spotify
valid_streams= df[df['msPlayed'] > 30000]
total = valid_streams['msPlayed'].sum()
print("Hours listened:", total / 1000.0 / 60.0 / 60.0)
# Out:
# Hours listened: 909.8294341666666

# %%
# get individual stream counts for each track in the past year (entire dataset)
stream_counts = valid_streams.groupby(['artistName','trackName']).size().reset_index(name='Streams').sort_values(by=['Streams'],ascending=False)
path = str(Path().absolute())
stream_counts.to_csv(path + '/entire_year.csv')
stream_counts.set_index(np.arange(1, len(stream_counts)+1)).head(50)
# Out:
#               artistName                                        trackName  \
# 1                TAEYEON                                             INVU
# 2                TAEYEON                             Can't Control Myself
# 3          Kim Kyung Rok                                      Sand Castle
# 4                TAEYEON                                          Toddler
# 5                TAEYEON                                      Some Nights
# 6                TAEYEON                                            Siren
# 7                TAEYEON                                         Timeless
# 8                TAEYEON                                     Cold As Hell
# 9                TAEYEON                               Set Myself On Fire
# 10                 HEIZE                                           HAPPEN
# 11               TAEYEON                                   Ending Credits
# 12           Michael Tai       A Tender Feeling (From "Sword Art Online")
# 13               TAEYEON                                            VOICE
# 14               TAEYEON                                            Heart
# 15                  BUZZ                                               가시
# 16               TAEYEON                                     Four Seasons
# 17               TAEYEON                                          Weekend
# 18               TAEYEON                                             Blue
# 19               TAEYEON                                    No Love Again
# 20  Two Door Cinema Club                          Changing of the Seasons
# 21                K.Will  Back In Time (The Moon during the Day X K.will)
# 22                    IU                                        Love poem
# 23          Taylor Swift                               champagne problems
# 24               TAEYEON                                                I
# 25               TAEYEON                                       Time Lapse
# 26               TAEYEON                                   You Better Not
# 27          Standing Egg                                           오래된 노래
# 28                 Adele                               When We Were Young
# 29         Sarah Kinsley                                            Karma
# 30               TAEYEON                               What Do I Call You
# 31           The Killers                                            Human
# 32         Kenshi Yonezu                                             カナリヤ
# 33               October                                             From
# 34               FINNEAS                                  Only A Lifetime
# 35               TAEYEON                                            Spark
# 36               TAEYEON                                             Fine
# 37               October                                            Intro
# 38          Jung Dong Ha                                 I Still Love You
# 39                  AKMU      Hey kid, Close your eyes (with Lee Sun Hee)
# 40               TAEYEON                                             Wine
# 41               TAEYEON                                              Why
# 42               TAEYEON                                          Gravity
# 43               TAEYEON                                     Feel So Fine
# 44              Coldplay                                    The Scientist
# 45               October                                          Journey
# 46                Joohyo                                   Northern Light
# 47           M.C the Max                                just looking 바라보기
# 48                    IU                                           My sea
# 49              The Rose                                She's In The Rain
# 50               TAEYEON                                            11:11
#
#     Streams
# 1       462
# 2       390
# 3       259
# 4       182
# 5       178
# 6       161
# 7       153
# 8       148
# 9       138
# 10      137
# 11      135
# 12      126
# 13      121
# 14      115
# 15      108
# 16       98
# 17       98
# 18       90
# 19       88
# 20       83
# 21       82
# 22       79
# 23       79
# 24       76
# 25       74
# 26       74
# 27       74
# 28       67
# 29       65
# 30       64
# 31       61
# 32       59
# 33       57
# 34       53
# 35       52
# 36       48
# 37       47
# 38       46
# 39       46
# 40       46
# 41       46
# 42       46
# 43       45
# 44       45
# 45       44
# 46       42
# 47       41
# 48       39
# 49       39
# 50       39

# %% [markdown]
# ### 3. Streaming data for 2022

# %%
# get top 10 artists from 2022 and the number of streams
streams_2022 = valid_streams[valid_streams['endTime'] > '2022-01-01']
artist_counts = streams_2022['artistName'].value_counts()
artist_counts.head(10)
# Out:
# TAEYEON          2817
# Kenshi Yonezu     389
# Glen Check        163
# Taylor Swift      144
# 10cm              134
# October           114
# FINNEAS           108
# mol-74             97
# IU                 90
# Michael Tai        63
# Name: artistName, dtype: int64

# %%
# look at streams from 2022 instead of the past year:
streams_2022_counts =streams_2022.groupby(['artistName','trackName']).size().reset_index(name='Streams').sort_values(by=['Streams'],ascending=False)
path = str(Path().absolute())

# output 2022 stream data into 2022.csv
streams_2022_counts.to_csv(path + '/2022.csv')

# %%
# search for a specific song:
song_name = 'INVU'

song_stream_count = streams_2022_counts[streams_2022_counts['trackName'] == song_name]
song_stream_count.head(10)
# Out:
#      artistName trackName  Streams
# 1339    TAEYEON      INVU      462

# %%
# search for a specific artist:
artist_name = 'TAEYEON'

artist_stream_counts = streams_2022_counts[streams_2022_counts['artistName'] == artist_name]
artist_stream_counts.set_index(np.arange(1, len(artist_stream_counts)+1)).head(50)
# Out:
#    artistName             trackName  Streams
# 1     TAEYEON                  INVU      462
# 2     TAEYEON  Can't Control Myself      390
# 3     TAEYEON               Toddler      182
# 4     TAEYEON           Some Nights      178
# 5     TAEYEON                 Siren      161
# 6     TAEYEON              Timeless      153
# 7     TAEYEON          Cold As Hell      148
# 8     TAEYEON    Set Myself On Fire      138
# 9     TAEYEON        Ending Credits      135
# 10    TAEYEON                 Heart      115
# 11    TAEYEON         No Love Again       88
# 12    TAEYEON                  Blue       75
# 13    TAEYEON        You Better Not       74
# 14    TAEYEON               Weekend       52
# 15    TAEYEON          Four Seasons       47
# 16    TAEYEON            Time Lapse       28
# 17    TAEYEON                     I       27
# 18    TAEYEON                 Spark       22
# 19    TAEYEON                  Wine       20
# 20    TAEYEON    What Do I Call You       19
# 21    TAEYEON          Feel So Fine       17
# 22    TAEYEON                  Fine       16
# 23    TAEYEON                 11:11       16
# 24    TAEYEON           Better Babe       15
# 25    TAEYEON                   LOL       13
# 26    TAEYEON                   Why       13
# 27    TAEYEON               Gravity       13
# 28    TAEYEON            By My Side       12
# 29    TAEYEON             Here I Am       11
# 30    TAEYEON            My Tragedy       10
# 31    TAEYEON         Love in Color        9
# 32    TAEYEON               Find Me        9
# 33    TAEYEON   Drawing Our Moments        9
# 34    TAEYEON                    If        8
# 35    TAEYEON             City Love        8
# 36    TAEYEON       Do You Love Me?        8
# 37    TAEYEON             Rescue Me        8
# 38    TAEYEON   Love You Like Crazy        7
# 39    TAEYEON               Dear Me        7
# 40    TAEYEON      Make Me Love You        6
# 41    TAEYEON                I'm OK        6
# 42    TAEYEON                 VOICE        6
# 43    TAEYEON          Lonely Night        5
# 44    TAEYEON                Circus        5
# 45    TAEYEON              Cover Up        5
# 46    TAEYEON                  Fire        5
# 47    TAEYEON            I Got Love        5
# 48    TAEYEON      When I Was Young        5
# 49    TAEYEON            Sweet Love        4
# 50    TAEYEON                Stress        4

# %% [markdown]
# ### 2022 Spotify Wrapped (so far)

# %%
# see your Spotify Wrapped so far
streams_2022_counts.set_index(np.arange(1, len(streams_2022_counts)+1)).head(100)
# Out:
#                artistName                                          trackName  \
# 1                 TAEYEON                                               INVU
# 2                 TAEYEON                               Can't Control Myself
# 3                 TAEYEON                                            Toddler
# 4                 TAEYEON                                        Some Nights
# 5                 TAEYEON                                              Siren
# 6                 TAEYEON                                           Timeless
# 7                 TAEYEON                                       Cold As Hell
# 8                 TAEYEON                                 Set Myself On Fire
# 9                 TAEYEON                                     Ending Credits
# 10                TAEYEON                                              Heart
# 11                TAEYEON                                      No Love Again
# 12                TAEYEON                                               Blue
# 13                TAEYEON                                     You Better Not
# 14          Kenshi Yonezu                                               カナリヤ
# 15                TAEYEON                                            Weekend
# 16                TAEYEON                                       Four Seasons
# 17           Taylor Swift                                 champagne problems
# 18                     IU                                          Love poem
# 19             Glen Check                                   Dazed & Confused
# 20                   10cm                             Fine Thank You And You
# 21                  aespa                                        YEPPI YEPPI
# 22          Fleetwood Mac                                          Landslide
# 23          Kenshi Yonezu                                              Lemon
# 24                TAEYEON                                         Time Lapse
# 25                TAEYEON                                                  I
# 26                 Basick  Meeting is easy, parting is hard (Feat. Leella...
# 27            Michael Tai         A Tender Feeling (From "Sword Art Online")
# 28           Taylor Swift                                  this is me trying
# 29           Philip Glass  String Quartet No. 3, "Mishima": VI. Mishima /...
# 30      Rex Orange County                                         KEEP IT UP
# 31                FINNEAS                                       Love is Pain
# 32                  Sting  What Could Have Been feat. Ray Chen (from the ...
# 33                BIGBANG                                         Still Life
# 34                TAEYEON                                              Spark
# 35          Kenshi Yonezu                                            ナンバーナイン
# 36        Frédéric Chopin                Nocturnes, Op. 48: No. 1 in C Minor
# 37                  Lorde                                          Liability
# 38                FINNEAS                                    Only A Lifetime
# 39                   10cm                                      That's Not...
# 40                TAEYEON                                               Wine
# 41    TOMORROW X TOGETHER                                        LO$ER=LO♡ER
# 42                TAEYEON                                 What Do I Call You
# 43          Kenshi Yonezu                                         Nighthawks
# 44                  Adele                                        To Be Loved
# 45             Blake Rose                                               Gone
# 46                TAEYEON                                       Feel So Fine
# 47               Coldplay                                      The Scientist
# 48          Kenshi Yonezu                                                 飛燕
# 49                   10cm                                   그대와 나 You And Me
# 50       Vincent Diamante                                             Flight
# 51        Reese Lansangan                              What Is This Feeling?
# 52                  Adele                                 When We Were Young
# 53                MC MONG                   Sick enough to die (Feat. JAMIE)
# 54           Anson Seabra                                       Emerald Eyes
# 55                   10cm                                        스토커 Stalker
# 56                 JAURIM                                            Shining
# 57                TAEYEON                                               Fine
# 58          Kenshi Yonezu                                             ピースサイン
# 59                TAEYEON                                              11:11
# 60             Glen Check                                              Waves
# 61                October                                       Recollection
# 62                TAEYEON                                        Better Babe
# 63          Kenshi Yonezu                                              orion
# 64          Kenshi Yonezu                                              LOSER
# 65          Fleetwood Mac                      Seven Wonders - 2017 Remaster
# 66          Kenshi Yonezu                                    砂の惑星 ( + 初音ミク )
# 67          Kenshi Yonezu                                             カムパネルラ
# 68                FINNEAS                          What They'll Say About Us
# 69   Cigarettes After Sex                                            Sunsetz
# 70                 Joohyo                                     Northern Light
# 71            John Powell  Romantic Flight - From How To Train Your Drago...
# 72             Glen Check                                               Sins
# 73           Taylor Swift                                          gold rush
# 74          Kenshi Yonezu                     愛麗絲(正式表記はAliceの中国語簡体字表記となります。)
# 75           Yu-Peng Chen                                    Tender Strength
# 76                TAEYEON                                                LOL
# 77             Bea Miller                                    i can't breathe
# 78                TAEYEON                                                Why
# 79                 mol-74                                             ミラーソング
# 80           Philip Glass                                Tales from the Loop
# 81          Gracie Abrams                                             Camden
# 82                TAEYEON                                            Gravity
# 83             Glen Check                   Sometimes You Gotta Shake It Off
# 84          Kenshi Yonezu                                            まちがいさがし
# 85                   MGMT                                               Kids
# 86          Kenshi Yonezu                                               打上花火
# 87                TAEYEON                                         By My Side
# 88        Phoebe Bridgers                                           Punisher
# 89              Lee So Ra                                            Track 9
# 90             Lee Yun Ji                                          My Family
# 91   Cigarettes After Sex                                                 K.
# 92             Glen Check                                    Dive Baby, Dive
# 93                Woodkid  Guns for Hire (from the series Arcane League o...
# 94          Kenshi Yonezu                                    灰色と青 ( + 菅田将暉 )
# 95              Amber Run                                                5AM
# 96           Taylor Swift                                        tolerate it
# 97          Kenshi Yonezu                              fogbound ( + 池田エライザ )
# 98           Jung Dong Ha                                   I Still Love You
# 99                 mol-74                                            Answers
# 100             Judy Kuhn  Colors of the Wind - From "Pocahontas" / Sound...
#
#      Streams
# 1        462
# 2        390
# 3        182
# 4        178
# 5        161
# 6        153
# 7        148
# 8        138
# 9        135
# 10       115
# 11        88
# 12        75
# 13        74
# 14        59
# 15        52
# 16        47
# 17        47
# 18        32
# 19        31
# 20        31
# 21        30
# 22        30
# 23        30
# 24        28
# 25        27
# 26        27
# 27        25
# 28        24
# 29        24
# 30        24
# 31        24
# 32        24
# 33        22
# 34        22
# 35        22
# 36        21
# 37        21
# 38        20
# 39        20
# 40        20
# 41        19
# 42        19
# 43        19
# 44        18
# 45        17
# 46        17
# 47        17
# 48        17
# 49        17
# 50        17
# 51        17
# 52        17
# 53        16
# 54        16
# 55        16
# 56        16
# 57        16
# 58        16
# 59        16
# 60        15
# 61        15
# 62        15
# 63        15
# 64        15
# 65        15
# 66        15
# 67        14
# 68        14
# 69        14
# 70        14
# 71        14
# 72        14
# 73        14
# 74        13
# 75        13
# 76        13
# 77        13
# 78        13
# 79        13
# 80        13
# 81        13
# 82        13
# 83        12
# 84        12
# 85        12
# 86        12
# 87        12
# 88        12
# 89        12
# 90        12
# 91        12
# 92        12
# 93        11
# 94        11
# 95        11
# 96        11
# 97        11
# 98        11
# 99        11
# 100       11
